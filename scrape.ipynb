# %%
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sb
from wordcloud import WordCloud

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/victornomwesigwa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/victornomwesigwa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Scrape all of Jane Austen’s writing
corpus = nltk.corpus.gutenberg.raw('austen-sense.txt')

# %%
tokens = nltk.tokenize.word_tokenize(corpus)

# %%
new_tokens=[word.lower() for word in tokens if word.isalpha()]

# %%
from nltk.corpus import stopwords
sw = nltk.corpus.stopwords.words('english')

# %%
words = []
words_ns = []
# Add to words_ns all words that are in words but not in sw
for word in new_tokens:
    if word not in sw:
        words_ns.append(word)
    else:
        words.append(word)

# %%
len(words)
# Out:
# 65874

# %%
words[:10]
# Out:
# ['and', 'by', 'the', 'of', 'had', 'been', 'in', 'their', 'was', 'and']

# %%
len(words_ns)
# Out:
# 52398

# %%
words_ns[:10]
# Out:
# ['sense',
#  'sensibility',
#  'jane',
#  'austen',
#  'chapter',
#  'family',
#  'dashwood',
#  'long',
#  'settled',
#  'sussex']

# %% [markdown]
# ## What are the most frequent words in Jane Austen?

# %%
# Figures inline and set visualization style
# %matplotlib inline
sb.set()

# %%
word_cloud_text = str1 = ' '.join(words_ns)
wordcloud = WordCloud().generate(word_cloud_text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## How often do the stop words in Jane Austen occur?

# %%
freqdist1 = nltk.FreqDist(words)
freqdist1.plot(25, title="Frequently used stopwords")
# Out:
# <AxesSubplot:title={'center':'Frequently used stopwords'}, xlabel='Samples', ylabel='Counts'>
